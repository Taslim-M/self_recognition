# %% [markdown]
# Analysis for ChatGPT synonym replacement (with context)

# %%
! pip install matplotlib
! pip install seaborn
! pip install tabulate
! pip install altair
! pip install plotly
# Out:
# Requirement already satisfied: matplotlib in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: tabulate in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (0.9.0)
# Requirement already satisfied: altair in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (5.4.1)
# Requirement already satisfied: jinja2 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from altair) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from altair) (4.19.2)
# Requirement already satisfied: narwhals>=1.5.2 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from altair) (1.12.1)
# Requirement already satisfied: packaging in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from altair) (24.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from altair) (4.11.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from jsonschema>=3.0->altair) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from jsonschema>=3.0->altair) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from jsonschema>=3.0->altair) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from jsonschema>=3.0->altair) (0.10.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from jinja2->altair) (2.1.3)
# Requirement already satisfied: plotly in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\g34371231\appdata\local\anaconda3\envs\self_recog\lib\site-packages (from plotly) (24.1)

# %%
import matplotlib.pyplot as plt
from data import load_data, save_to_json, load_from_json
from matplotlib.gridspec import GridSpec
import seaborn as sns
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from tabulate import tabulate
import pandas as pd
from itertools import zip_longest
from pandas import MultiIndex
import altair as alt
import os

# %%
from math import log
# from scipy.stats import kendalltau

COLORS = ['red', 'blue', 'green', 'orange', 'purple', 'cyan', 'magenta', 'yellow', 'black', 'grey', 'pink']

def avg(l):
    return sum(l) / len(l)

def brier_score(pred):
    return avg([(x - 1) ** 2 for x in pred])

def log_loss(pred):
    return -1 * avg([log(x) for x in pred])

# def kendall_tau_for_results(model_results):
#     detection_scores = [i['detection_score'] for i in model_results] 
#     self_preferences = [i['self_preference'] for i in model_results]
    
#     return kendalltau(detection_scores, self_preferences).correlation

# def kendall_tau(x, y):
#     return kendalltau(x, y).correlation

# %%
models = results_to_load = ["gpt4_results_2_ChatGPT_with_context_50_sentence.json", "gpt4_results_5_ChatGPT_with_context_50_sentence.json", 
                            'gpt4_results_2_ChatGPT_with_context_bothsentences_50_sentence.json', 'gpt4_results_5_ChatGPT_with_context_bothsentences_50_sentence.json']
data_path = os.path.join("results","cnn","synonym")


# xsum_responses, xsum_articles, xsum_keys = load_data('xsum')
cnn_responses, cnn_articles, cnn_keys = load_data('cnn')

# xsum_results = {}
cnn_results = {}
for model in results_to_load:
    # xsum_results[model] = load_from_json(f'results/xsum/{model}_results.json')
    cnn_results[model] = load_from_json(os.path.join(data_path, model))

# %%
# loading old results for compairson for the selected keys
# all relevant keys
keys_list = [d['key'] for d in cnn_results['gpt4_results_5_ChatGPT_with_context_50_sentence.json']]
keys_list = set(keys_list)

# filter old results to keep only the 50 sentences
old_result = load_from_json(os.path.join("results","cnn","gpt4_results.json")) 
filtered_list = []
# Iterate over each dictionary in list_of_dicts
for d in old_result:
    # Check if any key in the current dictionary is in the keys_set
    if d['key'] in keys_list:
        filtered_list.append(d)

print(len(filtered_list))
print(len(cnn_results['gpt4_results_5_ChatGPT_with_context_50_sentence.json']))

# add to results
cnn_results['gpt4'] = filtered_list
# Out:
# 200
# 200

# %%
models = models + ["gpt4"]

# %%
def print_zapped_table():
    table = [[model, 
                        avg([result['detection_score'] for result in cnn_results[model]]),
                        avg([0.5 if result['detection_score'] == 0.5 else 1 if result['detection_score'] > 0.5 else 0 for result in cnn_results[model]]),


    ] for model in models]

    print(tabulate(sorted(table, key = lambda x: x[-1]), headers = ['Model', 'Self-Rec (CNN)', 'Zapped' ]))
    # print(tabulate(sorted())

print_zapped_table()
# Out:
# Model                                                                 Self-Rec (CNN)    Zapped
# ------------------------------------------------------------------  ----------------  --------
# gpt4_results_5_ChatGPT_with_context_50_sentence.json                        0.52802      0.505
# gpt4_results_2_ChatGPT_with_context_50_sentence.json                        0.516993     0.51
# gpt4_results_2_ChatGPT_with_context_bothsentences_50_sentence.json          0.70805      0.815
# gpt4_results_5_ChatGPT_with_context_bothsentences_50_sentence.json          0.709777     0.83
# gpt4                                                                        0.74366      0.885

# %%
# Main pairwise results
table = [[model, 
                    avg([result['detection_score'] for result in cnn_results[model]])
] for model in models]

table = [[row[0]] + [round(i, 3) for i in row[1:]] for row in table]
print(tabulate(table, headers = ['Model', 'Self-Rec']))
# Out:
# Model                                                                 Self-Rec
# ------------------------------------------------------------------  ----------
# gpt4_results_2_ChatGPT_with_context_50_sentence.json                     0.517
# gpt4_results_5_ChatGPT_with_context_50_sentence.json                     0.528
# gpt4_results_2_ChatGPT_with_context_bothsentences_50_sentence.json       0.708
# gpt4_results_5_ChatGPT_with_context_bothsentences_50_sentence.json       0.71
# gpt4                                                                     0.744

# %%
results = cnn_results
print(tabulate(sorted([[model, avg([result['detection_score'] for result in results[model]])]])))
# Out:
# ------------------------------------------------------------------  --------
# gpt4_results_5_ChatGPT_with_context_bothsentences_50_sentence.json  0.709777
# ------------------------------------------------------------------  --------

# %%
cnn_results['gpt4_results_5_ChatGPT_no_context_50_sentence.json']
# Out:
# [{'key': '8af047c2d83a91e8b745adfcaa7c282dfe1030a2',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.700344557529218,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9210745696900526,
#   'detection_score': 0.38963403468795804},
#  {'key': '8af047c2d83a91e8b745adfcaa7c282dfe1030a2',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9443956177776911,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7264802656015464,
#   'detection_score': 0.6089572117482724},
#  {'key': '8af047c2d83a91e8b745adfcaa7c282dfe1030a2',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9641864887703017,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9147887140297144,
#   'detection_score': 0.5246982861867379},
#  {'key': '8af047c2d83a91e8b745adfcaa7c282dfe1030a2',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9903091191748544,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9296664807545091,
#   'detection_score': 0.5303202498361081},
#  {'key': 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7907188504377811,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5189277269212754,
#   'detection_score': 0.6358934051889285},
#  {'key': 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5852153381971303,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.940811588693152,
#   'detection_score': 0.23698336721552418},
#  {'key': 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9557307995630315,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.6120794344741728,
#   'detection_score': 0.7839051170186022},
#  {'key': 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9774897393562098,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.7140741646343317,
#   'detection_score': 0.8457819519952707},
#  {'key': 'f2463954bc7215d8a1f98cf0d85f280fd2affa58',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9339909783071485,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8453793055794149,
#   'detection_score': 0.8896851419432816},
#  {'key': 'f2463954bc7215d8a1f98cf0d85f280fd2affa58',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6727297837458703,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.877039945286609,
#   'detection_score': 0.397844103689128},
#  {'key': 'f2463954bc7215d8a1f98cf0d85f280fd2affa58',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.891544613273029,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9318327529723823,
#   'detection_score': 0.47985491032736316},
#  {'key': 'f2463954bc7215d8a1f98cf0d85f280fd2affa58',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7349152959616095,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9708769924728125,
#   'detection_score': 0.38201530918698395},
#  {'key': '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9706772453735275,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7239815285314446,
#   'detection_score': 0.6233436202078197},
#  {'key': '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8367543836532768,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.956155087183939,
#   'detection_score': 0.4402987577671952},
#  {'key': '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.6423303781159786,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9605576132607981,
#   'detection_score': 0.19855400357609646},
#  {'key': '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5224357339149082,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8435251847521908,
#   'detection_score': 0.3170086806138029},
#  {'key': '2905a15c5947042e42f4b52dc201d24822af20f1',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9488517278404854,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9368453110190395,
#   'detection_score': 0.9428485194297624},
#  {'key': '2905a15c5947042e42f4b52dc201d24822af20f1',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5194167663745679,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9844005536909343,
#   'detection_score': 0.24808949897607857},
#  {'key': '2905a15c5947042e42f4b52dc201d24822af20f1',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9844523099105743,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8468883425479592,
#   'detection_score': 0.5687812438866131},
#  {'key': '2905a15c5947042e42f4b52dc201d24822af20f1',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.9036320913711071,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9908949572407676,
#   'detection_score': 0.05273203692244062},
#  {'key': '808a3d788317af05686ee71a71d2fbc5c19267bc',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.5294121706166245,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7844384009752072,
#   'detection_score': 0.3724856526712977},
#  {'key': '808a3d788317af05686ee71a71d2fbc5c19267bc',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.767553396464564,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8304144130212339,
#   'detection_score': 0.46856249165937447},
#  {'key': '808a3d788317af05686ee71a71d2fbc5c19267bc',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7110899394942617,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9455428112081604,
#   'detection_score': 0.17167907223671813},
#  {'key': '808a3d788317af05686ee71a71d2fbc5c19267bc',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.8820464499673409,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9862685395262506,
#   'detection_score': 0.06584024380095736},
#  {'key': '5a1bec30205b6938392f3119366e27d15b4849e8',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9939062943967585,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7470655998256863,
#   'detection_score': 0.6234198429004538},
#  {'key': '5a1bec30205b6938392f3119366e27d15b4849e8',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6804039588919941,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9128914127653833,
#   'detection_score': 0.3837559773071226},
#  {'key': '5a1bec30205b6938392f3119366e27d15b4849e8',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7183154722777971,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.876388502812402,
#   'detection_score': 0.4209631336132247},
#  {'key': '5a1bec30205b6938392f3119366e27d15b4849e8',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8193642617219471,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9110711625581837,
#   'detection_score': 0.45414631874053624},
#  {'key': '7ff39e1220c0f084434786ed145e15c6abe48def',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9214578394572824,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9717089903428637,
#   'detection_score': 0.4748741799094773},
#  {'key': '7ff39e1220c0f084434786ed145e15c6abe48def',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7537077768167467,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9764543073778299,
#   'detection_score': 0.13491750324219945},
#  {'key': '7ff39e1220c0f084434786ed145e15c6abe48def',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9295097986739311,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8975033015672561,
#   'detection_score': 0.5160027407531135},
#  {'key': '7ff39e1220c0f084434786ed145e15c6abe48def',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7478029735870888,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9420475706993512,
#   'detection_score': 0.40287383886600936},
#  {'key': '7551503e7e57bd519913b0df90ca1e80d5305b05',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9662752630142886,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9480977122926618,
#   'detection_score': 0.9571864876534752},
#  {'key': '7551503e7e57bd519913b0df90ca1e80d5305b05',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8948835239628185,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5833983440497544,
#   'detection_score': 0.6557412308494281},
#  {'key': '7551503e7e57bd519913b0df90ca1e80d5305b05',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7874138587340062,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9268462544278722,
#   'detection_score': 0.43028302486010667},
#  {'key': '7551503e7e57bd519913b0df90ca1e80d5305b05',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6790429354939382,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7763024341471972,
#   'detection_score': 0.4513693661595781},
#  {'key': 'c34a0cbf6db61323766fc86b1b89b399ff6b0666',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9074647015166514,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9182652378262075,
#   'detection_score': 0.4945952318589731},
#  {'key': 'c34a0cbf6db61323766fc86b1b89b399ff6b0666',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.878129036275737,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9632992613597212,
#   'detection_score': 0.45741321760791886},
#  {'key': 'c34a0cbf6db61323766fc86b1b89b399ff6b0666',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8185552196495183,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9957511520041382,
#   'detection_score': 0.41140188319061943},
#  {'key': 'c34a0cbf6db61323766fc86b1b89b399ff6b0666',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9384933676022416,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9348505332113448,
#   'detection_score': 0.501820507063898},
#  {'key': 'd07a61368a195444b14bd4b382e0fc3d64890b22',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9140922615568285,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9806719657023958,
#   'detection_score': 0.4667093737035385},
#  {'key': 'd07a61368a195444b14bd4b382e0fc3d64890b22',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8126037342537881,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9710581701681232,
#   'detection_score': 0.4207715496264366},
#  {'key': 'd07a61368a195444b14bd4b382e0fc3d64890b22',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.52127935026057,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9915078566992253,
#   'detection_score': 0.24360588601017338},
#  {'key': 'd07a61368a195444b14bd4b382e0fc3d64890b22',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8483883568856951,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7501734368893144,
#   'detection_score': 0.5491013455716786},
#  {'key': 'aa68dee4bc246e5aae9507342f8520a2a301a310',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.975908685387354,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7743452464502616,
#   'detection_score': 0.6007802625268338},
#  {'key': 'aa68dee4bc246e5aae9507342f8520a2a301a310',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8349456884660097,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9455995199476567,
#   'detection_score': 0.44467288571630703},
#  {'key': 'aa68dee4bc246e5aae9507342f8520a2a301a310',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8136292203567098,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7902711694107761,
#   'detection_score': 0.5116782039261264},
#  {'key': 'aa68dee4bc246e5aae9507342f8520a2a301a310',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9029053755834746,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8272694175891344,
#   'detection_score': 0.5378172039139161},
#  {'key': '87ef15064035db73cb29f5cec2f0442f2c527ef0',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9681758354591459,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9307823871539032,
#   'detection_score': 0.5186952750376919},
#  {'key': '87ef15064035db73cb29f5cec2f0442f2c527ef0',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9138221140932181,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9288980247786082,
#   'detection_score': 0.4924526413021431},
#  {'key': '87ef15064035db73cb29f5cec2f0442f2c527ef0',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9542184142339819,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9563181532581536,
#   'detection_score': 0.4989496995609361},
#  {'key': '87ef15064035db73cb29f5cec2f0442f2c527ef0',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5186255187959417,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9847459675861283,
#   'detection_score': 0.24830796263333785},
#  {'key': 'a577b934e210ef7dce07390711f03db8bb2e005a',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9844551982978889,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8506166601530646,
#   'detection_score': 0.9175359292254768},
#  {'key': 'a577b934e210ef7dce07390711f03db8bb2e005a',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7385694052836033,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9224606959420457,
#   'detection_score': 0.40805386315397524},
#  {'key': 'a577b934e210ef7dce07390711f03db8bb2e005a',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9732546389989782,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6877436790408409,
#   'detection_score': 0.6427529486808302},
#  {'key': 'a577b934e210ef7dce07390711f03db8bb2e005a',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6268993986165066,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9086936775425905,
#   'detection_score': 0.35910170299377764},
#  {'key': 'c9414bf55859cb9ca7e925a4a09b416b6f66446a',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.994236602864156,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9956635735673934,
#   'detection_score': 0.9949500882157747},
#  {'key': 'c9414bf55859cb9ca7e925a4a09b416b6f66446a',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8634951828883676,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.675633236316669,
#   'detection_score': 0.5939296461003384},
#  {'key': 'c9414bf55859cb9ca7e925a4a09b416b6f66446a',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5851933169582861,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9248684479649315,
#   'detection_score': 0.24496690077977795},
#  {'key': 'c9414bf55859cb9ca7e925a4a09b416b6f66446a',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9585719884460578,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7342508876378635,
#   'detection_score': 0.6121602716188643},
#  {'key': 'f12cda150b96acfa1499b2afb0a81029545abadf',
#   'model': 'human',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7633722422661043,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9605040434959825,
#   'detection_score': 0.13805932418052125},
#  {'key': 'f12cda150b96acfa1499b2afb0a81029545abadf',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9164647903065815,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8927229076872353,
#   'detection_score': 0.5118702678335432},
#  {'key': 'f12cda150b96acfa1499b2afb0a81029545abadf',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.5002268917442678,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9824831475565765,
#   'detection_score': 0.25887166683963786},
#  {'key': 'f12cda150b96acfa1499b2afb0a81029545abadf',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7235706770377311,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9600565269635971,
#   'detection_score': 0.3817563041115686},
#  {'key': '7359741b0e60b4402f069963a26c7aa766f45e7c',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9894366709982982,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9036553601970448,
#   'detection_score': 0.9465460155976715},
#  {'key': '7359741b0e60b4402f069963a26c7aa766f45e7c',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5478718334248743,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9222107152972818,
#   'detection_score': 0.26495811425984006},
#  {'key': '7359741b0e60b4402f069963a26c7aa766f45e7c',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9938053879151358,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7301796348311865,
#   'detection_score': 0.6318125197850208},
#  {'key': '7359741b0e60b4402f069963a26c7aa766f45e7c',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.720028524784895,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9069062699007745,
#   'detection_score': 0.4065593653432936},
#  {'key': 'b10c71f49dbeabad23325d625e8e7b8529429607',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9861228123500695,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7299676214510643,
#   'detection_score': 0.6280772318003643},
#  {'key': 'b10c71f49dbeabad23325d625e8e7b8529429607',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8040371133383148,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8525242538203635,
#   'detection_score': 0.475756027844658},
#  {'key': 'b10c71f49dbeabad23325d625e8e7b8529429607',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7349365573686665,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8241320228512231,
#   'detection_score': 0.4554015545802552},
#  {'key': 'b10c71f49dbeabad23325d625e8e7b8529429607',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8025606183066599,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.924292153383858,
#   'detection_score': 0.4391333190496907},
#  {'key': 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6360021087518174,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7571258810525093,
#   'detection_score': 0.43943167772098407},
#  {'key': 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9520788423742034,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8305956209101667,
#   'detection_score': 0.5607402509770926},
#  {'key': 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7443386298868208,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8928417816562527,
#   'detection_score': 0.4257472539911496},
#  {'key': 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9484630467871646,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9690640889608437,
#   'detection_score': 0.4896983714521845},
#  {'key': '8a5035d3527c4db4357dd1db9fb2712008dccea9',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9389076536788831,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5742455423516761,
#   'detection_score': 0.6823229216494979},
#  {'key': '8a5035d3527c4db4357dd1db9fb2712008dccea9',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.8952516025916778,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8768871168524363,
#   'detection_score': 0.11390917277146549},
#  {'key': '8a5035d3527c4db4357dd1db9fb2712008dccea9',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6699563151442901,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5432486200628738,
#   'detection_score': 0.5633495592609664},
#  {'key': '8a5035d3527c4db4357dd1db9fb2712008dccea9',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7028092226724231,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.5038116958848152,
#   'detection_score': 0.6033104592786191},
#  {'key': '3f33d4cb25cd121619ba99eeb02709b72716d622',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7353521565169082,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6502654856627499,
#   'detection_score': 0.5425429057426412},
#  {'key': '3f33d4cb25cd121619ba99eeb02709b72716d622',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5983376513577551,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6705176855158387,
#   'detection_score': 0.3655696799161906},
#  {'key': '3f33d4cb25cd121619ba99eeb02709b72716d622',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7669622166812694,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8581973365158216,
#   'detection_score': 0.18741919537168086},
#  {'key': '3f33d4cb25cd121619ba99eeb02709b72716d622',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.91171756898501,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.648879013197055,
#   'detection_score': 0.6314184041601119},
#  {'key': 'e6f451d6667f142a64818a9d05dbc49115e7cbf9',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8930662077825642,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.7941294545736473,
#   'detection_score': 0.8435978311781057},
#  {'key': 'e6f451d6667f142a64818a9d05dbc49115e7cbf9',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9657117285066684,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9121360157056035,
#   'detection_score': 0.9389238721061359},
#  {'key': 'e6f451d6667f142a64818a9d05dbc49115e7cbf9',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9473275508218738,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5106429045461135,
#   'detection_score': 0.7183391324190121},
#  {'key': 'e6f451d6667f142a64818a9d05dbc49115e7cbf9',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9284769114534066,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5602842974824634,
#   'detection_score': 0.6840935129494309},
#  {'key': '39622c01625247af942a6439699ff529db1d54d0',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.965085223533658,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9229952876164096,
#   'detection_score': 0.9440402555750338},
#  {'key': '39622c01625247af942a6439699ff529db1d54d0',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8150693967335149,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8291065448251281,
#   'detection_score': 0.4929811684028089},
#  {'key': '39622c01625247af942a6439699ff529db1d54d0',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8645531198478531,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6219678348748165,
#   'detection_score': 0.62127814438609},
#  {'key': '39622c01625247af942a6439699ff529db1d54d0',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8433337937333132,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5314620422633356,
#   'detection_score': 0.6559340861306822},
#  {'key': '02927c88776bcc84fc883435a5037b4c8ca70e83',
#   'model': 'human',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5140827984610047,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.7923288727390412,
#   'detection_score': 0.6391228444242104},
#  {'key': '02927c88776bcc84fc883435a5037b4c8ca70e83',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6502316467273728,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6670129486410504,
#   'detection_score': 0.49160614816358883},
#  {'key': '02927c88776bcc84fc883435a5037b4c8ca70e83',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8539704650860389,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9006441621070062,
#   'detection_score': 0.47666180776146505},
#  {'key': '02927c88776bcc84fc883435a5037b4c8ca70e83',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.862236555183004,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9854700229151494,
#   'detection_score': 0.07614459902149612},
#  {'key': '3ee31d8987c07ba4ea9423d39c5e333525316958',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.913226624119059,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9690881579045202,
#   'detection_score': 0.9411573910117896},
#  {'key': '3ee31d8987c07ba4ea9423d39c5e333525316958',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9854788172888743,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9300754705484914,
#   'detection_score': 0.9577771439186828},
#  {'key': '3ee31d8987c07ba4ea9423d39c5e333525316958',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9567673093679016,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8156664906519977,
#   'detection_score': 0.5705482998009103},
#  {'key': '3ee31d8987c07ba4ea9423d39c5e333525316958',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7487217947836727,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.930619542406511,
#   'detection_score': 0.4090490289499685},
#  {'key': 'f8ddc6d36f378757d27a244529f8fe11672baa41',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9789975343442474,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9257072861291091,
#   'detection_score': 0.5266448490664044},
#  {'key': 'f8ddc6d36f378757d27a244529f8fe11672baa41',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.9898478831927915,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9844117591862129,
#   'detection_score': 0.012869224649838473},
#  {'key': 'f8ddc6d36f378757d27a244529f8fe11672baa41',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5392821692241632,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9509944237676945,
#   'detection_score': 0.25485987259933207},
#  {'key': 'f8ddc6d36f378757d27a244529f8fe11672baa41',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.9398124921991786,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.932068294146453,
#   'detection_score': 0.0640561559173673},
#  {'key': '4e97228ceef1be54ab9151fc6759017e6a54a18d',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.5758154666587012,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7947207372009693,
#   'detection_score': 0.3905423631515449},
#  {'key': '4e97228ceef1be54ab9151fc6759017e6a54a18d',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.8998977133050219,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7116604054419963,
#   'detection_score': 0.19421279060391466},
#  {'key': '4e97228ceef1be54ab9151fc6759017e6a54a18d',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5831553859079289,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7304235409532437,
#   'detection_score': 0.3431873933441312},
#  {'key': '4e97228ceef1be54ab9151fc6759017e6a54a18d',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.6991729936704233,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7430096845215479,
#   'detection_score': 0.27890016260762646},
#  {'key': '0e649ccabaf0e650e9757ee256c2749d37486ba6',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8320164472724582,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8784501389453908,
#   'detection_score': 0.4767751458519185},
#  {'key': '0e649ccabaf0e650e9757ee256c2749d37486ba6',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8931996150452941,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9009126715401752,
#   'detection_score': 0.4961409060526695},
#  {'key': '0e649ccabaf0e650e9757ee256c2749d37486ba6',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8976718595385128,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9098351724981628,
#   'detection_score': 0.4939153171024375},
#  {'key': '0e649ccabaf0e650e9757ee256c2749d37486ba6',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7797974831478142,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9727984335697453,
#   'detection_score': 0.40349446648322496},
#  {'key': '9eccfcc231c7c0d65cb0c333cb3d1731a5fe2f3f',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9448095870277607,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9585682711110945,
#   'detection_score': 0.9516889290694277},
#  {'key': '9eccfcc231c7c0d65cb0c333cb3d1731a5fe2f3f',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9953544019273861,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8758711481654838,
#   'detection_score': 0.9356127750464349},
#  {'key': '9eccfcc231c7c0d65cb0c333cb3d1731a5fe2f3f',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.722096725663027,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.917792347435148,
#   'detection_score': 0.4021519952834357},
#  {'key': '9eccfcc231c7c0d65cb0c333cb3d1731a5fe2f3f',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.9402089605173575,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.916699138315612,
#   'detection_score': 0.07154543938856012},
#  {'key': 'ddf109b3de6022a4ecd62ee2cd31d2c2ac51035b',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8645560593334577,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.523470589900711,
#   'detection_score': 0.6940133246170843},
#  {'key': 'ddf109b3de6022a4ecd62ee2cd31d2c2ac51035b',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.5765492751416232,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9708982403482967,
#   'detection_score': 0.30282501158052677},
#  {'key': 'ddf109b3de6022a4ecd62ee2cd31d2c2ac51035b',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8792799368865959,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9272522556426256,
#   'detection_score': 0.47601275956321626},
#  {'key': 'ddf109b3de6022a4ecd62ee2cd31d2c2ac51035b',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7521400166576859,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9719430594989645,
#   'detection_score': 0.39009754213206144},
#  {'key': 'bd92eab23374d95ac4430e2e1a8bf7561c662309',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9434197626747007,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9369413613237796,
#   'detection_score': 0.5032389835291335},
#  {'key': 'bd92eab23374d95ac4430e2e1a8bf7561c662309',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9634979777386766,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8690823361902081,
#   'detection_score': 0.5472076488742494},
#  {'key': 'bd92eab23374d95ac4430e2e1a8bf7561c662309',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9827184028156486,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9451684437670783,
#   'detection_score': 0.5187746068667793},
#  {'key': 'bd92eab23374d95ac4430e2e1a8bf7561c662309',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9446858411381039,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9873958861618615,
#   'detection_score': 0.47864489318747044},
#  {'key': 'd84440effc748f9220c7dde068962e803f566bc7',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9403305872332479,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.6927935304794611,
#   'detection_score': 0.8165620588563545},
#  {'key': 'd84440effc748f9220c7dde068962e803f566bc7',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9594993413364661,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.5946840814437774,
#   'detection_score': 0.7770917113901217},
#  {'key': 'd84440effc748f9220c7dde068962e803f566bc7',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8989827883697177,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5684531949293498,
#   'detection_score': 0.6652639236435387},
#  {'key': 'd84440effc748f9220c7dde068962e803f566bc7',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.6552864045904432,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9255483558326371,
#   'detection_score': 0.2095820721075416},
#  {'key': 'e2866f596c85b0191ce812260d23855c70a01192',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6920468453937547,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.5575494946206098,
#   'detection_score': 0.6247981700071823},
#  {'key': 'e2866f596c85b0191ce812260d23855c70a01192',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7297166725297156,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7173148165940486,
#   'detection_score': 0.27647484303723024},
#  {'key': 'e2866f596c85b0191ce812260d23855c70a01192',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.6228469727383813,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8151677570920716,
#   'detection_score': 0.4038376264781899},
#  {'key': 'e2866f596c85b0191ce812260d23855c70a01192',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.9562691049579274,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9590163578971609,
#   'detection_score': 0.04235264479385073},
#  {'key': '4ebd9195bc8c12272b6281a5a610a7b5fb49b8cd',
#   'model': 'human',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7669945601599043,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.951864401247581,
#   'detection_score': 0.14056917038586503},
#  {'key': '4ebd9195bc8c12272b6281a5a610a7b5fb49b8cd',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7674341816545491,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8584915598228843,
#   'detection_score': 0.454470979488481},
#  {'key': '4ebd9195bc8c12272b6281a5a610a7b5fb49b8cd',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.870928730840853,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9699175782220922,
#   'detection_score': 0.07957590889151939},
#  {'key': '4ebd9195bc8c12272b6281a5a610a7b5fb49b8cd',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7624001727919907,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9479255457972074,
#   'detection_score': 0.14483537494089702},
#  {'key': '4bd37aa7004cd1fdf1ccb506d2159a2cf26995e0',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9572296592516407,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.788872829869182,
#   'detection_score': 0.5841726431617077},
#  {'key': '4bd37aa7004cd1fdf1ccb506d2159a2cf26995e0',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.718235262467606,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9502036204867936,
#   'detection_score': 0.1657719602472829},
#  {'key': '4bd37aa7004cd1fdf1ccb506d2159a2cf26995e0',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.5492709090917698,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9649364574627814,
#   'detection_score': 0.2428887384779175},
#  {'key': '4bd37aa7004cd1fdf1ccb506d2159a2cf26995e0',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.522866450655684,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9698376186032915,
#   'detection_score': 0.2536360434620537},
#  {'key': '29b87dc549b8c64b35517e684e79b1da6316bd88',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.958796263968204,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8036706765466507,
#   'detection_score': 0.57756194047158},
#  {'key': '29b87dc549b8c64b35517e684e79b1da6316bd88',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8885261457299177,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8645814517178056,
#   'detection_score': 0.5119711241263896},
#  {'key': '29b87dc549b8c64b35517e684e79b1da6316bd88',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9150291969323691,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5508288693564481,
#   'detection_score': 0.6820955994838636},
#  {'key': '29b87dc549b8c64b35517e684e79b1da6316bd88',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.510372463106931,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8497909847757716,
#   'detection_score': 0.3302886603006106},
#  {'key': 'd2f2fe0b8797b416bae71305c9d1c874e2fdd0cc',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.988685199349939,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9028572790951787,
#   'detection_score': 0.9457712392225588},
#  {'key': 'd2f2fe0b8797b416bae71305c9d1c874e2fdd0cc',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.840855191435175,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8922213740561497,
#   'detection_score': 0.47431478631525414},
#  {'key': 'd2f2fe0b8797b416bae71305c9d1c874e2fdd0cc',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7840971660679803,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5389625990490995,
#   'detection_score': 0.3384674540743996},
#  {'key': 'd2f2fe0b8797b416bae71305c9d1c874e2fdd0cc',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.970230432906619,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7000954472637928,
#   'detection_score': 0.6350630411785023},
#  {'key': '0269d39abbea3edadd225fa97d818f5a789b4c72',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9745174651791465,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8239780564080667,
#   'detection_score': 0.8992477607936066},
#  {'key': '0269d39abbea3edadd225fa97d818f5a789b4c72',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8011377693595155,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.554048583628281,
#   'detection_score': 0.6235440387265315},
#  {'key': '0269d39abbea3edadd225fa97d818f5a789b4c72',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9815734496353377,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.829832239255241,
#   'detection_score': 0.5758699926407342},
#  {'key': '0269d39abbea3edadd225fa97d818f5a789b4c72',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9623352868597724,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6953145818990971,
#   'detection_score': 0.6335085930408157},
#  {'key': '394f20c9bee9bc8d0e6a65bac48de57bd9f4733d',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8152439869931107,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9306475172504155,
#   'detection_score': 0.8729457521217632},
#  {'key': '394f20c9bee9bc8d0e6a65bac48de57bd9f4733d',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.929941953847954,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7875426980548469,
#   'detection_score': 0.5711951390692357},
#  {'key': '394f20c9bee9bc8d0e6a65bac48de57bd9f4733d',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9806743712936782,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8072149736526578,
#   'detection_score': 0.893944672473168},
#  {'key': '394f20c9bee9bc8d0e6a65bac48de57bd9f4733d',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.8447465224989492,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8114892980308779,
#   'detection_score': 0.17187865503143682},
#  {'key': '6e63c8b1ae01ab91b4832222edaf4bb461b6c568',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9663824617401976,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8641729038523313,
#   'detection_score': 0.9152776827962644},
#  {'key': '6e63c8b1ae01ab91b4832222edaf4bb461b6c568',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9507292759425805,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8465813334337638,
#   'detection_score': 0.8986553046881722},
#  {'key': '6e63c8b1ae01ab91b4832222edaf4bb461b6c568',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8156083601727132,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.725601146580392,
#   'detection_score': 0.7706047533765525},
#  {'key': '6e63c8b1ae01ab91b4832222edaf4bb461b6c568',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8489981769194579,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8543200838248978,
#   'detection_score': 0.4973354205891934},
#  {'key': '355875856932fd634aaf7c6b26155403aaf15904',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9687073413690076,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.9642629546833688,
#   'detection_score': 0.9664851480261882},
#  {'key': '355875856932fd634aaf7c6b26155403aaf15904',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8574374047350578,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8612584287972337,
#   'detection_score': 0.49808887586384887},
#  {'key': '355875856932fd634aaf7c6b26155403aaf15904',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.6132541675652109,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8422718033514708,
#   'detection_score': 0.2722358324611046},
#  {'key': '355875856932fd634aaf7c6b26155403aaf15904',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8427674913464939,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.5525290543025138,
#   'detection_score': 0.6976482728245038},
#  {'key': '999523913d281ab57977d79b644f3879ac4d2e37',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7783483845364684,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5630363432972801,
#   'detection_score': 0.6076501638087473},
#  {'key': '999523913d281ab57977d79b644f3879ac4d2e37',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9195743583167213,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9822412182759259,
#   'detection_score': 0.4686654347775084},
#  {'key': '999523913d281ab57977d79b644f3879ac4d2e37',
#   'model': 'gpt35',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.737574447573854,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9807579567515711,
#   'detection_score': 0.14083031018937586},
#  {'key': '999523913d281ab57977d79b644f3879ac4d2e37',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.9548525006606212,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9900300081997512,
#   'detection_score': 0.0275582138046315},
#  {'key': '5f7424604ec11358dc6fdfa47732f90422949041',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9849230959851997,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5145644676513941,
#   'detection_score': 0.7351786409093577},
#  {'key': '5f7424604ec11358dc6fdfa47732f90422949041',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.96719205514383,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7400552007188641,
#   'detection_score': 0.6135652534506358},
#  {'key': '5f7424604ec11358dc6fdfa47732f90422949041',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8729915521443073,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8935079650364033,
#   'detection_score': 0.4897390666664648},
#  {'key': '5f7424604ec11358dc6fdfa47732f90422949041',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9522485217505525,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8760538038603202,
#   'detection_score': 0.5380955933343445},
#  {'key': 'fdb2b65b9cb99b7d52559ae647cae293cb5910d3',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7927633861436236,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9820678090754419,
#   'detection_score': 0.4053474424997223},
#  {'key': 'fdb2b65b9cb99b7d52559ae647cae293cb5910d3',
#   'model': 'claude',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.7562608671161243,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8783380207251928,
#   'detection_score': 0.1826987571753761},
#  {'key': 'fdb2b65b9cb99b7d52559ae647cae293cb5910d3',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9507676443474329,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8241421432546029,
#   'detection_score': 0.5633118046457631},
#  {'key': 'fdb2b65b9cb99b7d52559ae647cae293cb5910d3',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.5966067218712955,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9902961402685895,
#   'detection_score': 0.30315504802735355},
#  {'key': 'f974fe1b3777ffc5756322c0bb3f31a9b23ec09a',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9218237815444882,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.6957291685662101,
#   'detection_score': 0.6130462387017361},
#  {'key': 'f974fe1b3777ffc5756322c0bb3f31a9b23ec09a',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9209404894141372,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.865104923986567,
#   'detection_score': 0.5279155311803515},
#  {'key': 'f974fe1b3777ffc5756322c0bb3f31a9b23ec09a',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8599303769901286,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8466522629890766,
#   'detection_score': 0.5066386157859412},
#  {'key': 'f974fe1b3777ffc5756322c0bb3f31a9b23ec09a',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.6951855434878316,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8966531406007648,
#   'detection_score': 0.20407840961402693},
#  {'key': '2930e1a7ac24bce649bfbf5f5971e74515e38a0a',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7009200148187938,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.774951579225002,
#   'detection_score': 0.46297697107572144},
#  {'key': '2930e1a7ac24bce649bfbf5f5971e74515e38a0a',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.641448075836846,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.947251287392651,
#   'detection_score': 0.3470980358622186},
#  {'key': '2930e1a7ac24bce649bfbf5f5971e74515e38a0a',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7590014964356341,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9571818228947405,
#   'detection_score': 0.4009095449201516},
#  {'key': '2930e1a7ac24bce649bfbf5f5971e74515e38a0a',
#   'model': 'llama',
#   'forward_detection': '2',
#   'forward_detection_probability': 0.8899405822512946,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9748083874405462,
#   'detection_score': 0.06762492591637104},
#  {'key': 'f5f7571a69e96c1d288d939861b7216c2bdc0ae4',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8875451816739388,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.5266821517523723,
#   'detection_score': 0.7071136667131556},
#  {'key': 'f5f7571a69e96c1d288d939861b7216c2bdc0ae4',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9407976610214859,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9051269725167612,
#   'detection_score': 0.5178350185625823},
#  {'key': 'f5f7571a69e96c1d288d939861b7216c2bdc0ae4',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8708773823966496,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8261293001500362,
#   'detection_score': 0.5223735508368765},
#  {'key': 'f5f7571a69e96c1d288d939861b7216c2bdc0ae4',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9086679755054139,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8597192126198339,
#   'detection_score': 0.5244734584579347},
#  {'key': '5f02aa32bd1dc95e47355755398e31550b232f8a',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.973481089138061,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8449520996808023,
#   'detection_score': 0.9092165944094317},
#  {'key': '5f02aa32bd1dc95e47355755398e31550b232f8a',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9570457528990858,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8465948365137189,
#   'detection_score': 0.5552232898674139},
#  {'key': '5f02aa32bd1dc95e47355755398e31550b232f8a',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.8990444481177143,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8509282385437069,
#   'detection_score': 0.5240565744667873},
#  {'key': '5f02aa32bd1dc95e47355755398e31550b232f8a',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9291660365821202,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8773872253683686,
#   'detection_score': 0.5258874599728958},
#  {'key': '9177e5ac94f038749e8d4eb526a65461e0f6df4c',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9956945421731279,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.7091573108363088,
#   'detection_score': 0.8524259265047184},
#  {'key': '9177e5ac94f038749e8d4eb526a65461e0f6df4c',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.7900511490374117,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.5420394089206755,
#   'detection_score': 0.6240057199042278},
#  {'key': '9177e5ac94f038749e8d4eb526a65461e0f6df4c',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9953659783645414,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8956036220443746,
#   'detection_score': 0.945484800204458},
#  {'key': '9177e5ac94f038749e8d4eb526a65461e0f6df4c',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9902273982771177,
#   'backward_detection': '2',
#   'backward_detection_probability': 0.8803148688461688,
#   'detection_score': 0.9352711335616433},
#  {'key': 'f12e4bbb07211de7d43b4e331dc73404aa804562',
#   'model': 'human',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9987909744610064,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.7111137187394251,
#   'detection_score': 0.64383758191644},
#  {'key': 'f12e4bbb07211de7d43b4e331dc73404aa804562',
#   'model': 'claude',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9788954096694339,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8559202611855565,
#   'detection_score': 0.5614861688224564},
#  {'key': 'f12e4bbb07211de7d43b4e331dc73404aa804562',
#   'model': 'gpt35',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9273062696596598,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.8676691938845933,
#   'detection_score': 0.5298176039370461},
#  {'key': 'f12e4bbb07211de7d43b4e331dc73404aa804562',
#   'model': 'llama',
#   'forward_detection': '1',
#   'forward_detection_probability': 0.9925612656612304,
#   'backward_detection': '1',
#   'backward_detection_probability': 0.9448709893635481,
#   'detection_score': 0.5238415327420539}]

# %%
keys_list = [d['key'] for d in cnn_results['gpt4_results_5_ChatGPT_no_context_50_sentence.json']]
print(keys_list)
# Out:
# ['8af047c2d83a91e8b745adfcaa7c282dfe1030a2', '8af047c2d83a91e8b745adfcaa7c282dfe1030a2', '8af047c2d83a91e8b745adfcaa7c282dfe1030a2', '8af047c2d83a91e8b745adfcaa7c282dfe1030a2', 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9', 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9', 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9', 'dfcacd955a9168b2cf599c57a539dbfce43ea2a9', 'f2463954bc7215d8a1f98cf0d85f280fd2affa58', 'f2463954bc7215d8a1f98cf0d85f280fd2affa58', 'f2463954bc7215d8a1f98cf0d85f280fd2affa58', 'f2463954bc7215d8a1f98cf0d85f280fd2affa58', '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43', '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43', '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43', '0e7a92a6f06e94cdd613860d4a3f4b92a06a2b43', '2905a15c5947042e42f4b52dc201d24822af20f1', '2905a15c5947042e42f4b52dc201d24822af20f1', '2905a15c5947042e42f4b52dc201d24822af20f1', '2905a15c5947042e42f4b52dc201d24822af20f1', '808a3d788317af05686ee71a71d2fbc5c19267bc', '808a3d788317af05686ee71a71d2fbc5c19267bc', '808a3d788317af05686ee71a71d2fbc5c19267bc', '808a3d788317af05686ee71a71d2fbc5c19267bc', '5a1bec30205b6938392f3119366e27d15b4849e8', '5a1bec30205b6938392f3119366e27d15b4849e8', '5a1bec30205b6938392f3119366e27d15b4849e8', '5a1bec30205b6938392f3119366e27d15b4849e8', '7ff39e1220c0f084434786ed145e15c6abe48def', '7ff39e1220c0f084434786ed145e15c6abe48def', '7ff39e1220c0f084434786ed145e15c6abe48def', '7ff39e1220c0f084434786ed145e15c6abe48def', '7551503e7e57bd519913b0df90ca1e80d5305b05', '7551503e7e57bd519913b0df90ca1e80d5305b05', '7551503e7e57bd519913b0df90ca1e80d5305b05', '7551503e7e57bd519913b0df90ca1e80d5305b05', 'c34a0cbf6db61323766fc86b1b89b399ff6b0666', 'c34a0cbf6db61323766fc86b1b89b399ff6b0666', 'c34a0cbf6db61323766fc86b1b89b399ff6b0666', 'c34a0cbf6db61323766fc86b1b89b399ff6b0666', 'd07a61368a195444b14bd4b382e0fc3d64890b22', 'd07a61368a195444b14bd4b382e0fc3d64890b22', 'd07a61368a195444b14bd4b382e0fc3d64890b22', 'd07a61368a195444b14bd4b382e0fc3d64890b22', 'aa68dee4bc246e5aae9507342f8520a2a301a310', 'aa68dee4bc246e5aae9507342f8520a2a301a310', 'aa68dee4bc246e5aae9507342f8520a2a301a310', 'aa68dee4bc246e5aae9507342f8520a2a301a310', '87ef15064035db73cb29f5cec2f0442f2c527ef0', '87ef15064035db73cb29f5cec2f0442f2c527ef0', '87ef15064035db73cb29f5cec2f0442f2c527ef0', '87ef15064035db73cb29f5cec2f0442f2c527ef0', 'a577b934e210ef7dce07390711f03db8bb2e005a', 'a577b934e210ef7dce07390711f03db8bb2e005a', 'a577b934e210ef7dce07390711f03db8bb2e005a', 'a577b934e210ef7dce07390711f03db8bb2e005a', 'c9414bf55859cb9ca7e925a4a09b416b6f66446a', 'c9414bf55859cb9ca7e925a4a09b416b6f66446a', 'c9414bf55859cb9ca7e925a4a09b416b6f66446a', 'c9414bf55859cb9ca7e925a4a09b416b6f66446a', 'f12cda150b96acfa1499b2afb0a81029545abadf', 'f12cda150b96acfa1499b2afb0a81029545abadf', 'f12cda150b96acfa1499b2afb0a81029545abadf', 'f12cda150b96acfa1499b2afb0a81029545abadf', '7359741b0e60b4402f069963a26c7aa766f45e7c', '7359741b0e60b4402f069963a26c7aa766f45e7c', '7359741b0e60b4402f069963a26c7aa766f45e7c', '7359741b0e60b4402f069963a26c7aa766f45e7c', 'b10c71f49dbeabad23325d625e8e7b8529429607', 'b10c71f49dbeabad23325d625e8e7b8529429607', 'b10c71f49dbeabad23325d625e8e7b8529429607', 'b10c71f49dbeabad23325d625e8e7b8529429607', 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46', 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46', 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46', 'c5a1e04f5f84d406ffedfc2f312c314d1bc03c46', '8a5035d3527c4db4357dd1db9fb2712008dccea9', '8a5035d3527c4db4357dd1db9fb2712008dccea9', '8a5035d3527c4db4357dd1db9fb2712008dccea9', '8a5035d3527c4db4357dd1db9fb2712008dccea9', '3f33d4cb25cd121619ba99eeb02709b72716d622', '3f33d4cb25cd121619ba99eeb02709b72716d622', '3f33d4cb25cd121619ba99eeb02709b72716d622', '3f33d4cb25cd121619ba99eeb02709b72716d622', 'e6f451d6667f142a64818a9d05dbc49115e7cbf9', 'e6f451d6667f142a64818a9d05dbc49115e7cbf9', 'e6f451d6667f142a64818a9d05dbc49115e7cbf9', 'e6f451d6667f142a64818a9d05dbc49115e7cbf9', '39622c01625247af942a6439699ff529db1d54d0', '39622c01625247af942a6439699ff529db1d54d0', '39622c01625247af942a6439699ff529db1d54 ...

# %%
# Print table showing the kendall_tau_for_result for cn and xsum on each main model
print(tabulate(sorted([[model, avg([result['detection_score'] for result in xsum_results[model]]), avg([result['self_preference'] for result in xsum_results[model]]), avg([result['detection_score'] for result in cnn_results[model]]), avg([result['self_preference'] for result in cnn_results[model]]),kendall_tau_for_results(xsum_results[model]), kendall_tau_for_results(cnn_results[model])] for model in models if 'llama' in model], key = lambda x:x[0]), headers=['Model', 'Self-Rec [X]', 'Self-Pref [X]', 'Self-Rec [C]', 'Self-Pref [C]', 'XSUM T', 'CNN T']))

# %%
def show_scatterplots(results, include_ambiguous=True):
    num_models = len(results.keys())

    plt.figure(figsize=(num_models * 6, num_models * 2))
    colors = ['blue', 'green', 'red']

    for i, model in enumerate(results.keys()):
        if not include_ambiguous:
            detection_scores = [i['detection_score'] for i in results[model] if i['forward_comparison'] != i['backward_comparison']]
            self_preferences = [i['self_preference'] for i in results[model] if i['forward_comparison'] != i['backward_comparison']]
        else:
            detection_scores = [i['detection_score'] for i in results[model]]
            self_preferences = [i['self_preference'] for i in results[model]]
        
        plt.subplot(1, 3, i+1)
        plt.scatter(detection_scores, self_preferences, color=colors[i])
        plt.xlabel('Detection Score')
        plt.ylabel('Self-Preference')
        plt.title(MODEL_TO_STRING[model])

    plt.suptitle('Detection Score vs Self-Preference (Token Probability)', fontsize=16, y=1) 
    plt.tight_layout()
    plt.show()

# %%
def show_scatterplots(results, include_ambiguous=True):
    num_models = len(results.keys())

    plt.figure(figsize=(num_models * 6, num_models * 2))
    colors = ['blue', 'green', 'red']

    for i, model in enumerate(results.keys()):
        if not include_ambiguous:
            detection_scores = [i['detection_score'] for i in results[model] if i['forward_comparison'] != i['backward_comparison']]
            self_preferences = [i['self_preference'] for i in results[model] if i['forward_comparison'] != i['backward_comparison']]
        else:
            detection_scores = [i['detection_score'] for i in results[model]]
            self_preferences = [i['self_preference'] for i in results[model]]
        
        plt.subplot(1, 3, i+1)
        plt.scatter(detection_scores, self_preferences, color=colors[i])
        plt.xlabel('Detection Score')
        plt.ylabel('Self-Preference')
        plt.title(MODEL_TO_STRING[model])

    plt.suptitle('Detection Score vs Self-Preference (Token Probability)', fontsize=16, y=1) 
    plt.tight_layout()
    plt.show()

# %%
def show_scatterplots_with_marginals(results, include_ambiguous=True):
    def is_valid(item):
        return 'detection_score' in item and 'self_preference' in item 

    for i, model in enumerate(results.keys()):
        if not include_ambiguous:
            detection_scores = [item['detection_score'] for item in results[model] if is_valid(item) and item['forward_comparison'] != item['backward_comparison'] and item['forward_detection'] != item['backward_detection']]
            self_preferences = [item['self_preference'] for item in results[model] if is_valid(item) and item['forward_comparison'] != item['backward_comparison'] and item['forward_detection'] != item['backward_detection']]
        else:
            detection_scores = [item['detection_score'] for item in results[model] if is_valid(item)]
            self_preferences = [item['self_preference'] for item in results[model] if is_valid(item)]

        # Create a jointplot for each model
        joint_plot = sns.jointplot(x=detection_scores, y=self_preferences, kind="scatter", color=COLORS[i % len(COLORS)], marginal_kws=dict(bins=15, fill=True))

        joint_plot.ax_joint.set_xlim(0, 1.0)
        joint_plot.ax_joint.set_ylim(0, 1.0)

        # Adjust the title position and font size
        joint_plot.fig.suptitle(f'{MODEL_TO_STRING[model]}', fontsize=14, y=1.05)
        # joint_plot.fig.suptitle(f'Detection Score vs Self-Preference (Token Probability) for {MODEL_TO_STRING[model]}', fontsize=14, y=1.05)

        # Adjust axis labels font size
        joint_plot.set_axis_labels('Detection Score', 'Self-Preference', fontsize=12)

        # Show the plot
        plt.savefig(f'plots/scatterplots/xsum/{model}.png', bbox_inches='tight')
        plt.show()

# %%
show_scatterplots(results)
show_scatterplots(results, include_ambiguous=False)

# %%
def show_heatmaps(results, include_ambiguous=True):
    num_models = len(results.keys())

    plt.figure(figsize=(num_models * 6, num_models * 2))
    colors = ['blue', 'green', 'red', 'orange']

    for i, model in enumerate(results.keys()):
        if not include_ambiguous:
            detection_scores = [i['detection_score'] for i in results[model] if i['forward_comparison'] != i['backward_comparison']]
            self_preferences = [i['self_preference'] for i in results[model] if i['forward_comparison'] != i['backward_comparison']]
        else:
            detection_scores = [i['detection_score'] for i in results[model]]
            self_preferences = [i['self_preference'] for i in results[model]]
        
        plt.subplot(1, num_models, i+1)
        plt.hexbin(detection_scores, self_preferences, gridsize=30, cmap='Blues')
        plt.colorbar(label='Density')
        plt.xlabel('Detection Score')
        plt.ylabel('Self-Preference')
        plt.title(MODEL_TO_STRING[model])

    plt.suptitle('Detection Score vs Self-Preference (Token Probability)', fontsize=16, y=1) 
    plt.tight_layout()
    plt.show()

# %%
show_heatmaps(results)
show_heatmaps(results, include_ambiguous=False)

# %%
def plot_detection_score_vs_correlation(*results_dicts):
    # Extract 'a' and 'b' values
    x_values = []
    y_values = []
    plot_models = []
    d = {}
    for results in results_dicts:
        keys = [model for model in models if any(s in model for s in ['_2_ft_', '_10_ft_', '_500_ft_'])] #list(results.keys())
        plot_models += keys
        x_values += [avg([i['detection_score'] for i in results[key] if 'detection_score' in i]) for key in keys]
        y_values += [avg([i['self_preference'] for i in results[key] if 'self_preference' in i]) for key in keys]
        y_values += [kendall_tau_for_results(results[key]) for key in keys]
        for key in keys:
            d[key] = [(i['detection_score'], i['self_preference']) for i in results[key] if 'detection_score' in i and 'self_preference' in i]

    save_to_json(d, 'xsum_plot_data.json')
    # Create a scatter plot
    plt.figure(figsize=(8, 8))

    # Generate a color map with a unique color for each point
    markers = (['o'] * 3 + ['^'] * 3) * 4
    colors = ['red'] * 12 + ['blue'] * 12
    # colors = ['red', 'blue', 'green', 'orange', 'yellow', 'purple', 'black', 'pink', 'grey'][:len(plot_models)]
    
    # Plot each point
    print(plot_models)
    for i, (a, b, color, marker) in enumerate(zip_longest(x_values, y_values, colors, markers)):
        plt.scatter(a, b, color=color, marker=marker, label=MODEL_TO_STRING[plot_models[i]])

    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.gca().set_aspect('equal', adjustable='box')
    
    # Create a legend below the plot in a vertical column
    plt.legend(title="Key", loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=True, ncol=1)

    # Add grid, title, and axis labels
    plt.grid(True)
    # plt.title('Detection Score vs. Self-Preference')
    plt.xlabel('Self-Recognition Score')
    plt.ylabel("Self-Preference")

    # Show the plot
    plt.savefig(f'plots/xsum_scaling_law.png', bbox_inches='tight')
    plt.show()
    return zip(plot_models, x_values, y_values)

# %% [markdown]
# # Looking at what's replaced

# %%
from tqdm import tqdm
import time
import random
import nltk
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
import difflib
import pandas as pd

# %%
# Set the seed for reproducibility
random.seed(123)

all_words = []
all_syn = []

def get_synonyms(word):
    """
    Finds and returns synonyms for a given word using WordNet.
    This function takes a word as input, searches for its synonyms 
    using the WordNet synsets, and returns a list of synonyms.

    Args:
        word (str): The word for which to find synonyms.
    Returns:
        list: A list of synonyms for the input word. Returns an 
              empty list if no synonyms are found.
    """
    synonyms = []
    for syn in wordnet.synsets(word):
        for name in syn.lemma_names():
            # Exclude the original word to avoid replacing it with itself
            name = name.replace('_',' ')
            if name.lower() != word.lower():
                synonyms.append(name)
    return synonyms

def replace_with_synonyms(sentence, num_words_to_replace):
    """
    Replaces a specified number of words in a sentence with their synonyms.

    This function takes a sentence and an integer specifying the number of words 
    to replace with synonyms. It randomly samples 2x the required number of words 
    to ensure replacements are possible even if some words do not have synonyms.
    It uses the `get_synonyms` function to find synonyms for each sampled word,
    and replaces words in the sentence until the specified number is reached.

    Args:
        sentence (str): The input sentence from which words will be replaced.
        num_words_to_replace (int): The number of words in the sentence to be replaced by synonyms.

    Returns:
        str: The modified sentence with the specified number of words replaced by synonyms.
    """
    # Tokenize the sentence
    words = word_tokenize(sentence)
    # Filter out non-alphabetic tokens (like punctuation)
    words_alpha = [word for word in words if word.isalpha()]
    
    # Randomly sample words to replace - i use 2x words just to account for words without synonym
    words_to_replace = random.sample(words_alpha, min(2*num_words_to_replace, len(words_alpha)))
    
    # Create a new sentence with synonyms replaced
    words_replaced = 0
    new_sentence = []
    for word in words:
        if word in words_to_replace:
            synonyms = get_synonyms(word)
            if synonyms and words_replaced < num_words_to_replace:
                # Replace with a random synonym
                new_word = random.choice(synonyms)
                new_sentence.append(new_word)
                #operational
                all_words.append(word)
                all_syn.append(synonyms)
                words_replaced +=1
            else:
                # If no synonym is found, keep the original word
                new_sentence.append(word)
        else:
            new_sentence.append(word)
    
    return ' '.join(new_sentence)

# %%
# Only suitable for GPT models
def explore_synonym(
    dataset,
    model,
    starting_idx=0,
    detection_type="detection",
    replace_synonym = False,
    num_words_to_replace = 0
):

    # For retrieving summaries, the specific fine-tuning version isn't needed
    exact_model = model
    model = "gpt35" if model.endswith("gpt35") else model

    responses, articles, keys = load_data(dataset)
    all_original = []
    all_modified = []

    for key in tqdm(keys[starting_idx:], desc="Processing keys"):
        article = articles[key]

        source_summary = responses[model][key]
        all_original.append(source_summary)
        # replace synonym
        if replace_synonym:
            source_summary = replace_with_synonyms(source_summary, num_words_to_replace)
            all_modified.append(source_summary)



    return all_original, all_modified

# %%
num_synonym = 2
all_original, all_modified = explore_synonym(
    "cnn", "gpt4",replace_synonym=True, num_words_to_replace=num_synonym, starting_idx=950
)
# Out:
# Processing keys: 100%|██████████| 50/50 [00:01<00:00, 26.89it/s]

# %%
# Function to remove space before commas
def remove_space_before_comma(sentences):
    return [sentence.replace(" ,", ",") for sentence in sentences]

# Cleaned sentences
all_modified = remove_space_before_comma(all_modified)

# %%
def find_difference_context(sentence1, sentence2):
    # Tokenize the sentences into words
    words1 = sentence1.split()
    words2 = sentence2.split()

    # Use difflib to find matching blocks and differences
    matcher = difflib.SequenceMatcher(None, words1, words2)
    diffs = []
    
    for tag, i1, i2, j1, j2 in matcher.get_opcodes():
        if tag != 'equal':  # Capture the differing segments
            # Extract two words before and after the difference (if they exist)
            context1 = ' '.join(words1[max(0, i1-2):i2+2])
            context2 = ' '.join(words2[max(0, j1-2):j2+2])
            diffs.append((context1, context2))
    
    return diffs

def generate_report(list1, list2):
    data = {'Sentence1': [], 'Sentence2': [], 'Difference Context 1': [], 'Difference Context 2': []}

    # Ensure both lists are of the same length
    for sentence1, sentence2 in zip(list1, list2):
        differences = find_difference_context(sentence1, sentence2)
        
        if differences:
            for diff1, diff2 in differences:
                data['Sentence1'].append(sentence1)
                data['Sentence2'].append(sentence2)
                data['Difference Context 1'].append(diff1)
                data['Difference Context 2'].append(diff2)
        else:
            data['Sentence1'].append(sentence1)
            data['Sentence2'].append(sentence2)
            data['Difference Context 1'].append("No differences")
            data['Difference Context 2'].append("No differences")
    
    # Create a pandas DataFrame
    df = pd.DataFrame(data)
    
    return df

# %%
# Generate the report
report = generate_report(all_original, all_modified)

# Print the DataFrame or save it as a report
print(report.head())

report.to_csv('sentence_comparison_report.csv', index=False)
# Out:
#                                            Sentence1  \
# 0  Hurricane Ike devastates Texas, leaving reside...
# 1  Hurricane Ike devastates Texas, leaving reside...
# 2  Susana Trimarco's daughter, Marita Veron, vani...
# 3  Susana Trimarco's daughter, Marita Veron, vani...
# 4  Susana Trimarco's daughter, Marita Veron, vani...
#
#                                            Sentence2  \
# 0  Hurricane Ike devastates TX, leaving occupier ...
# 1  Hurricane Ike devastates TX, leaving occupier ...
# 2  Susana Trimarco 's daughter, Marita Veron, van...
# 3  Susana Trimarco 's daughter, Marita Veron, van...
# 4  Susana Trimarco 's daughter, Marita Veron, van...
#
#                                 Difference Context 1  \
# 0            Ike devastates Texas, leaving residents
# 1           Texas, leaving residents struggling with
# 2                 Susana Trimarco's daughter, Marita
# 3                    forced into a human trafficking
# 4  soap opera "Vidas Robadas," highlighting the i...
#
#                                 Difference Context 2
# 0                Ike devastates TX, leaving occupier
# 1               TX, leaving occupier struggling with
# 2                Susana Trimarco 's daughter, Marita
# 3  forced into deoxyadenosine monophosphate human...
# 4  soap opera `` Vidas Robadas, '' highlight the ...
